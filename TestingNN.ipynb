# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
import sklearn.model_selection
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn import metrics

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

from keras.models import Sequential
from keras import layers as nn
# Out:
# Using TensorFlow backend.

# %%
class evaluate_models:
    
    def __init__(self):
        return
        
    def ins_values(self,X_train,y_train,X_val,y_val):
        nb_classes = 7
        self.X_train = X_train
        self.y_train = np_utils.to_categorical(y_train,nb_classes)
        self.X_val = X_val
        self.y_val = np_utils.to_categorical(y_val,nb_classes)        
    
    def data(self):
        return X_train,y_train,X_val,y_val
    
    
    def test_architecture(self,X_train,y_train,X_val,y_val):
        cnn1,cnn2,cnn3 = create_models(X_train.shape[1])
        train_models([cnn1,cnn2,cnn3],X_train,y_train,X_val,y_val)
    
    def create_models(self,input_size):
        input_size = 100
        
        cnn1 = Sequential()
        cnn1.add(nn.Embedding(vocab_size, embedding_dim, input_length=maxlen))
        cnn1.add(nn.Dense(32, activation = 'relu', input_shape = (input_size,)))
        cnn1.add(nn.Conv1D(32, 5, activation='relu'))
        cnn1.add(nn.MaxPooling1D(pool_size = 2))
        cnn1.add(nn.Conv1D(64,5, activation='relu'))
        cnn1.add(nn.MaxPooling1D(pool_size = 2))
        cnn1.add(nn.Flatten())
        cnn1.add(nn.Dense(120, activation = 'relu'))
        cnn1.add(nn.Dense(86, activation = 'relu'))
        cnn1.add(nn.Dense(7, activation = 'softmax'))
        cnn1.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

        cnn2 = Sequential()
        cnn2.add(nn.Embedding(vocab_size, embedding_dim, input_length=maxlen))
        cnn2.add(nn.Dense(32, activation = 'relu', input_shape = (input_size,)))
        cnn2.add(nn.Conv1D(32, 5, activation='relu'))
        cnn2.add(nn.MaxPooling1D(pool_size = 2))
        cnn2.add(nn.Conv1D(64, 5, activation='relu'))
        cnn2.add(nn.MaxPooling1D(pool_size = 2))
        cnn2.add(nn.Conv1D(128, 5, activation='relu'))
        cnn2.add(nn.MaxPooling1D(pool_size = 2))
        cnn2.add(nn.Flatten())
        cnn2.add(nn.Dense(60, activation = 'relu'))
        cnn2.add(nn.Dense(7, activation = 'softmax'))
        cnn2.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

        cnn3 = Sequential()
        cnn3.add(nn.Embedding(vocab_size, embedding_dim, input_length=maxlen))
        cnn3.add(nn.Dense(32,activation = 'relu', input_shape = (input_size,)))
        cnn3.add(nn.Conv1D(16, 5, activation='relu'))
        cnn3.add(nn.Conv1D(16, 5, activation='relu'))
        cnn3.add(nn.MaxPooling1D(pool_size = 2))
        cnn3.add(nn.Conv1D(32, 5, activation = 'relu'))
        cnn3.add(nn.Conv1D(32, 5, activation = 'relu'))
        cnn3.add(nn.MaxPooling1D(pool_size = 2))
        cnn3.add(nn.Dense(256,activation = 'relu'))
        cnn3.add(nn.Dense(7, activation = 'softmax'))
        cnn3.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

        cnn1.summary()
        cnn2.summary()
        cnn3.summary()
        
        return cnn1,cnn2,cnn3

    def train_models(self,models, X_train,y_train,X_val,y_val):
        for model in models:
            history = model.fit(X_train,y_train,epochs = 2,verbose = False, validation_data = (X_val,y_val), batch_size = 50)
            loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
            print("Training Accuracy: {:.4f}".format(accuracy))
            loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
            print("Testing Accuracy:  {:.4f}".format(accuracy))
            plot_history(history)
            print()

# %%
vocab_size = 50
embedding_dim = 10
maxlen = 100
models = evaluate_models.create_models(10)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, 100, 10)           500
# _________________________________________________________________
# dense_31 (Dense)             (None, 100, 32)           352
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 96, 32)            5152
# _________________________________________________________________
# max_pooling1d_19 (MaxPooling (None, 48, 32)            0
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 44, 64)            10304
# _________________________________________________________________
# max_pooling1d_20 (MaxPooling (None, 22, 64)            0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1408)              0
# _________________________________________________________________
# dense_32 (Dense)             (None, 120)               169080
# _________________________________________________________________
# dense_33 (Dense)             (None, 86)                10406
# _________________________________________________________________
# dense_34 (Dense)             (None, 7)                 609
# =================================================================
# Total params: 196,403
# Trainable params: 196,403
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_14 (Embedding)     (None, 100, 10)           500
# _________________________________________________________________
# dense_35 (Dense)             (None, 100, 32)           352
# _________________________________________________________________
# conv1d_28 (Conv1D)           (None, 96, 32)            5152
# _________________________________________________________________
# max_pooling1d_21 (MaxPooling (None, 48, 32)            0
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 44, 64)            10304
# _________________________________________________________________
# max_pooling1d_22 (MaxPooling (None, 22, 64)            0
# _________________________________________________________________
# conv1d_30 (Conv1D)           (None, 18, 128)           41088
# _________________________________________________________________
# max_pooling1d_23 (MaxPooling (None, 9, 128)            0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 60)                69180
# _________________________________________________________________
# dense_37 (Dense)             (None, 7)                 427
# =================================================================
# Total params: 127,003
# Trainable params: 127,003
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_15 (Embedding)     (None, 100, 10)           500
# _________________________________________________________________
# dense_38 (Dense)             (None, 100, 32)           352
# _________________________________________________________________
# conv1d_31 (Conv1D)           (None, 96, 16)            2576
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 92, 16)            1296
# _________________________________________________________________
# max_pooling1d_24 (MaxPooling (None, 46, 16)            0
# _________________________________________________________________
# conv1d_33 (Conv1D)           (None, 42, 32)            2592
# _________________________________________________________________
# conv1d_34 (Conv1D)           (None, 38, 32)            5152
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, 19, 32)            0
# _________________________________________________________________
# dense_39 (Dense)             (None, 19, 256)           8448
# _________________________________________________________________
# dense_40 (Dense)             (None, 19, 7)             1799
# =================================================================
# Total params: 22,715
# Trainable params: 22,715
# Non-trainable params: 0
# _________________________________________________________________
